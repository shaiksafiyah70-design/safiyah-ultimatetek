# %%
# Add two numbers
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

sum = num1 + num2
print("Sum:", sum)
# Out:
# Enter first number:  8
# Enter second number:  9
# Sum: 17.0

# %%
# Calculate area of a rectangle
length = float(input("Enter length: "))
width = float(input("Enter width: "))

area = length * width
print("Area of the rectangle:", area)
# Out:
# Enter length:  7
# Enter width:  2
# Area of the rectangle: 14.0

# %%
# Convert Celsius to Fahrenheit
celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = (celsius * 9/5) + 32
print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Enter temperature in Celsius:  16
# Temperature in Fahrenheit: 60.8

# %%
num = int(input("Enter a number: "))

if num <= 1:
    print("Not a prime number")
else:
    for i in range(2, num):
        if num % i == 0:
            print("Not a prime number")
            break
    else:
        print("Prime number")
# Out:
# Enter a number:  87
# Not a prime number

# %%
import random

number = random.randint(1, 10)

guess = int(input("Guess a number between 1 and 10: "))

if guess == number:
    print("Congratulations! You guessed correctly.")
else:
    print("Wrong guess. The number was:", number)
# Out:
# Guess a number between 1 and 10:  8
# Wrong guess. The number was: 4

# %%
num = int(input("Enter a number: "))

for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
# Enter a number:  5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
rows = int(input("Enter number of rows: "))

for i in range(1, rows + 1):
    print("*" * i)
# Out:
# Enter number of rows:  9
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********

# %%
rows = int(input("Enter number of rows: "))

for i in range(1, rows + 1):
    print(" " * (rows - i) + "*" * (2 * i - 1))
# Out:
# Enter number of rows:  5
#     *
#    ***
#   *****
#  *******
# *********

# %%
contacts = {}

while True:
    print("\n1. Add Contact")
    print("2. View Contacts")
    print("3. Exit")

    choice = input("Enter choice: ")

    if choice == "1":
        name = input("Enter name: ")
        phone = input("Enter phone number: ")
        contacts[name] = phone
        print("Contact added!")

    elif choice == "2":
        if not contacts:
            print("No contacts found.")
        else:
            for name, phone in contacts.items():
                print(name, ":", phone)

    elif choice == "3":
        break

    else:
        print("Invalid choice")
# Out:
# 1. Add Contact
# 2. View Contacts
# 3. Exit
# Enter choice:  1
# Enter name:  safiyah
# Enter phone number:  6546531458
# Contact added!
#
# 1. Add Contact
# 2. View Contacts
# 3. Exit
# Enter choice:  2
# safiyah : 6546531458
#
# 1. Add Contact
# 2. View Contacts
# 3. Exit
# Enter choice:
# Invalid choice
#
# 1. Add Contact
# 2. View Contacts
# 3. Exit
# Enter choice:  3

# %%
numbers = [1, 2, 3, 4, 2, 5, 6, 3, 7]

duplicates = []
for num in numbers:
    if numbers.count(num) > 1 and num not in duplicates:
        duplicates.append(num)

print("Duplicate elements:", duplicates)
# Out:
# Duplicate elements: [2, 3]

# %%
sentence = input("Enter a sentence: ")

words = sentence.split()
frequency = {}

for word in words:
    if word in frequency:
        frequency[word] += 1
    else:
        frequency[word] = 1

print("Word frequency:")
for word, count in frequency.items():
    print(word, ":", count)
# Out:
# Enter a sentence:  hey! how are uh doing
# Word frequency:
# hey! : 1
# how : 1
# are : 1
# uh : 1
# doing : 1

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "Cannot divide by zero"

print("Select operation:")
print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")

choice = input("Enter choice (1/2/3/4): ")
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

if choice == "1":
    print("Result:", add(a, b))
elif choice == "2":
    print("Result:", subtract(a, b))
elif choice == "3":
    print("Result:", multiply(a, b))
elif choice == "4":
    print("Result:", divide(a, b))
else:
    print("Invalid choice")
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Enter choice (1/2/3/4):  1
# Enter first number:  8
# Enter second number:  6
# Result: 14.0

# %%
def validate_email(email):
    if "@" in email and "." in email:
        return True
    else:
        return False

email = input("Enter email address: ")

if validate_email(email):
    print("Valid email address")
else:
    print("Invalid email address")
# Out:
# Enter email address:  Shaiksaff@gmail.com
# Valid email address

# %%
import random
import string

def generate_password(length):
    characters = string.ascii_letters + string.digits + string.punctuation
    password = ""
    for i in range(length):
        password += random.choice(characters)
    return password

length = int(input("Enter password length: "))
print("Generated Password:", generate_password(length))
# Out:
# Enter password length:  10
# Generated Password: u;a8EPGQnb

# %%
import utils

print(utils.square(4))
print(utils.cube(3))
print(utils.is_even(10))
# Out:
# 16
# 27
# True

# %%
class BankAccount:
    def __init__(self, name, balance=0):
        self.name = name
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print("Deposited:", amount)

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print("Withdrawn:", amount)
        else:
            print("Insufficient balance")

    def show_balance(self):
        print("Current Balance:", self.balance)


# Using the class
account = BankAccount("Rahul", 1000)
account.deposit(500)
account.withdraw(300)
account.show_balance()
# Out:
# Deposited: 500
# Withdrawn: 300
# Current Balance: 1200

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.grades = []

    def add_grade(self, grade):
        self.grades.append(grade)

    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)

    def display(self):
        print("Student Name:", self.name)
        print("Grades:", self.grades)
        print("Average:", self.average_grade())


# Using the class
student = Student("safiyah")
student.add_grade(85)
student.add_grade(90)
student.add_grade(78)
student.display()
# Out:
# Student Name: safiyah
# Grades: [85, 90, 78]
# Average: 84.33333333333333

# %%
class Inventory:
    def __init__(self):
        self.items = {}

    def add_item(self, name, quantity):
        if name in self.items:
            self.items[name] += quantity
        else:
            self.items[name] = quantity
        print(name, "added to inventory")

    def remove_item(self, name, quantity):
        if name in self.items and self.items[name] >= quantity:
            self.items[name] -= quantity
            print(quantity, name, "removed")
        else:
            print("Not enough stock or item not found")

    def show_inventory(self):
        print("Inventory:")
        for item, qty in self.items.items():
            print(item, ":", qty)


# Using the class
store = Inventory()
store.add_item("Apple", 10)
store.add_item("Banana", 20)
store.remove_item("Apple", 5)
store.show_inventory()
# Out:
# Apple added to inventory
# Banana added to inventory
# 5 Apple removed
# Inventory:
# Apple : 5
# Banana : 20

# %%
def add_note(note):
    with open("notes.txt", "a") as file:
        file.write(note + "\n")
    print("Note saved successfully!")

def view_notes():
    try:
        with open("notes.txt", "r") as file:
            print("\nYour Notes:")
            print(file.read())
    except FileNotFoundError:
        print("No notes found.")


while True:
    print("\n1. Add Note")
    print("2. View Notes")
    print("3. Exit")

    choice = input("Enter choice: ")

    if choice == "1":
        note = input("Write your note: ")
        add_note(note)

    elif choice == "2":
        view_notes()

    elif choice == "3":
        break

    else:
        print("Invalid choice")
# Out:
# 1. Add Note
# 2. View Notes
# 3. Exit
# Enter choice:  1
# Write your note:  hey! ultimatetek solutions
# Note saved successfully!
#
# 1. Add Note
# 2. View Notes
# 3. Exit
# Enter choice:  2
# Your Notes:
# hey! ultimatetek solutions
#
#
# 1. Add Note
# 2. View Notes
# 3. Exit
# Enter choice:  3

# %%
import csv

total = 0
count = 0

try:
    with open("data.csv", "r") as file:
        reader = csv.DictReader(file)
        for row in reader:
            total += int(row["Marks"])
            count += 1

    print("Total Marks:", total)
    print("Average Marks:", total / count)

except FileNotFoundError:
    print("CSV file not found.")

except ValueError:
    print("Invalid data in CSV file.")
# Out:
# Total Marks: 3933
# Average Marks: 80.26530612244898

# %%
filename = input("Enter file name: ")

try:
    with open(filename, "r") as file:
        print(file.read())

except FileNotFoundError:
    print("Error: File not found.")

except PermissionError:
    print("Error: Permission denied.")

except Exception as e:
    print("Unexpected error:", e)

else:
    print("File read successfully.")

finally:
    print("Program finished.")
# Out:
# Enter file name:  data.csv
# Name,Marks
# Amit,80
# Neha,90
# Rahul,70
# Priya,85
# Suresh,78
# Anita,92
# Vikram,66
# Pooja,88
# Rohan,74
# Kavita,81
# Manish,69
# Sneha,95
# Arjun,72
# Meena,89
# Deepak,77
# Nisha,84
# Karan,68
# Shweta,91
# Aakash,73
# Divya,87
# Ramesh,65
# Sunita,90
# Mohit,76
# Anjali,93
# Sanjay,71
# Rekha,82
# Nitin,67
# Isha,88
# Pradeep,79
# Komal,94
# Varun,75
# Payal,86
# Harish,70
# Aditi,92
# Rajesh,64
# Simran,89
# Yogesh,77
# Pankaj,83
# Tanvi,90
# Alok,68
# Bhavna,91
# Sachin,74
# Kritika,88
# Mukesh,66
# Neelam,85
# Gaurav,72
# Ritu,93
# Ashok,69
# Pallavi,87
#
# File read successfully.
# Program finished.

# %%
import requests

url = "https://jsonplaceholder.typicode.com/posts"

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    
    # Print first 5 posts
    for post in data[:5]:
        print("ID:", post["id"])
        print("Title:", post["title"])
        print("Body:", post["body"])
        print("-" * 40)
else:
    print("Failed to fetch data")
# Out:
# ID: 1
# Title: sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# Body: quia et suscipit
# suscipit recusandae consequuntur expedita et cum
# reprehenderit molestiae ut ut quas totam
# nostrum rerum est autem sunt rem eveniet architecto
# ----------------------------------------
# ID: 2
# Title: qui est esse
# Body: est rerum tempore vitae
# sequi sint nihil reprehenderit dolor beatae ea dolores neque
# fugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis
# qui aperiam non debitis possimus qui neque nisi nulla
# ----------------------------------------
# ID: 3
# Title: ea molestias quasi exercitationem repellat qui ipsa sit aut
# Body: et iusto sed quo iure
# voluptatem occaecati omnis eligendi aut ad
# voluptatem doloribus vel accusantium quis pariatur
# molestiae porro eius odio et labore et velit aut
# ----------------------------------------
# ID: 4
# Title: eum et est occaecati
# Body: ullam et saepe reiciendis voluptatem adipisci
# sit amet autem assumenda provident rerum culpa
# quis hic commodi nesciunt rem tenetur doloremque ipsam iure
# quis sunt voluptatem rerum illo velit
# ----------------------------------------
# ID: 5
# Title: nesciunt quas odio
# Body: repudiandae veniam quaerat sunt sed
# alias aut fugiat sit autem sed est
# voluptatem omnis possimus esse voluptatibus quis
# est aut tenetur dolor neque
# ----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.bbc.com/news"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

headlines = soup.find_all("h3")

print("Top Headlines:\n")

for headline in headlines[:10]:
    print("-", headline.get_text())
# Out:
# Top Headlines:
#
# - The BBC is in multiple languages

# %%
import requests
from bs4 import BeautifulSoup
import os

url = "https://example.com"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# Create folder
os.makedirs("images", exist_ok=True)

images = soup.find_all("img")

for i, img in enumerate(images):
    img_url = img.get("src")

    if img_url and img_url.startswith("http"):
        img_data = requests.get(img_url).content

        with open(f"images/image_{i}.jpg", "wb") as file:
            file.write(img_data)

print("Images downloaded successfully!")
# Out:
# Images downloaded successfully!

# %%
pip install pdfplumber
# Out:
# Requirement already satisfied: pdfplumber in c:\users\safiyah\anaconda3\lib\site-packages (0.11.9)
# Requirement already satisfied: pdfminer.six==20251230 in c:\users\safiyah\anaconda3\lib\site-packages (from pdfplumber) (20251230)
# Requirement already satisfied: Pillow>=9.1 in c:\users\safiyah\anaconda3\lib\site-packages (from pdfplumber) (11.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\safiyah\anaconda3\lib\site-packages (from pdfplumber) (5.3.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\safiyah\anaconda3\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\safiyah\anaconda3\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\safiyah\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\safiyah\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfplumber

def extract_text_from_pdf(path):
    all_text = []
    with pdfplumber.open(path) as pdf:
        for page in pdf.pages:
            text = page.extract_text() or ""
            all_text.append(text.strip())
    return "\n\n".join(t for t in all_text if t)

if __name__ == "__main__":
    pdf_path = "sample.pdf"
    text = extract_text_from_pdf(pdf_path)
    print(text[:1099])  # preview
# Out:
# The Wonders of the Natural World
# Nature, in its boundless variety, has always inspired human curiosity and awe. From the
# smallest microorganism to the vast expanses of the cosmos, every element of the natural world
# plays a role in the intricate web of life. The forests, oceans, deserts, and mountains each tell a
# unique story, shaped by millennia of geological and biological processes. Understanding nature
# is not merely a scientific pursuit; it is also a pathway to appreciating the delicate balance that
# sustains life on Earth.
# Forests, often described as the lungs of the planet, are among the most critical ecosystems.
# They regulate the Earth's climate, purify the air, and provide shelter for countless species.
# Tropical rainforests, such as the Amazon, are particularly rich in biodiversity, harboring millions
# of plants, insects, and animals. Each layer of the forest, from the canopy to the forest floor,
# forms a complex habitat where life thrives in astonishing harmony. Deforestation and climate
# change threaten these ecosystems, making conservation efforts more urgent than ever.
# Oceans

# %%
from openai import OpenAI

client = OpenAI()

print("Simple Chatbot (type 'exit' to quit)\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Chatbot: Goodbye!")
        break

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful chatbot."},
            {"role": "user", "content": user_input}
        ]
    )

    reply = response.choices[0].message.content
    print("Chatbot:", reply)

# %%
from openai import OpenAI

client = OpenAI(api_key="sk-xxxxxxxxxxxxxxxxxxxx")


print("Simple Chatbot (type 'exit' to quit)\n")

messages = [
    {"role": "system", "content": "You are a helpful chatbot."}
]

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Chatbot: Goodbye!")
        break

    messages.append({"role": "user", "content": user_input})

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages
    )

    reply = response.choices[0].message.content
    print("Chatbot:", reply)

    messages.append({"role": "assistant", "content": reply})
# Out:
# Simple Chatbot (type 'exit' to quit)
# You:  hello
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[3], line 21
#      17     break
#      19 messages.append({"role": "user", "content": user_input})
# ---> 21 response = client.chat.completions.create(
#      22     model="gpt-4o-mini",
#      23     messages=messages
#      24 )
#      26 reply = response.choices[0].message.content
#      27 print("Chatbot:", reply)
#
# File ~\anaconda3\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\openai\resources\chat\completions\completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)
#    1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-xxxxx***********xxxx. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}

# %%
from openai import OpenAI

client = OpenAI()

text = input("Enter text to summarize:\n\n")

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You summarize text clearly and concisely."},
        {"role": "user", "content": f"Summarize the following text:\n{text}"}
    ],
    temperature=0.3
)

summary = response.choices[0].message.content
print("\nSummary:\n", summary)
